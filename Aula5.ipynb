# %%
import pandas as pd

# Import do data frame
url = 'https://s3.amazonaws.com/aulas-fiap/imdb-reviews-pt-br.csv'

# pandas read_csv with skiprows option
df = pd.read_csv(url, sep = ';', encoding='utf-8')
df.describe()


# Remover linhas com valores nulos
df.dropna(inplace=True)
df.shape
#df.nome_descricao[0]
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-1-c4ac5c8e9989> in <module>()
#       5
#       6 # pandas read_csv with skiprows option
# ----> 7 df = pd.read_csv(url, sep = ';', encoding='utf-8')
#       8 df.describe()
#       9
#
# ...
